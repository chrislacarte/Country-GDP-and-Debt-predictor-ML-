# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pycountry
import csv
import pycountry_convert as pc 
import sqlalchemy
from sqlalchemy import create_engine
import pymysql
from getpass import getpass

# %%
data_0 = pd.read_csv("WEO_Data.csv", sep=',')
data_0
# Out:
#       Country                                 Subject Descriptor       2015  \
# 0     Albania            Gross domestic product, constant prices      2.219
# 1     Albania             Gross domestic product, current prices     11.389
# 2     Albania                   Gross domestic product, deflator    194.969
# 3     Albania  Gross domestic product per capita, constant pr...  12,173.62
# 4     Albania                                   Total investment     26.237
# ...       ...                                                ...        ...
# 1451  Vietnam                         General government revenue      19.19
# 1452  Vietnam               General government total expenditure     24.174
# 1453  Vietnam           General government net lending/borrowing     -4.983
# 1454  Vietnam                      General government gross debt     46.116
# 1455  Vietnam                            Current account balance     -0.861
#
# ...

# %% [markdown]
# # INFO TABLE

# %%
info= pd.read_csv("WEO_info.csv", sep=',')
info
# Out:
#               Gross domestic product, constant prices  \
# 0              Gross domestic product, current prices
# 1                    Gross domestic product, deflator
# 2   Gross domestic product per capita, constant pr...
# 3                                    Total investment
# 4                              Gross national savings
# 5                  Inflation, average consumer prices
# 6             Volume of imports of goods and services
# 7             Volume of exports of goods and services
# 8                                   Unemployment rate
# 9                                          Population
# 10                         General government revenue
# 11               General government total expenditure
# 12           General government net lending/borrowing
# 13                      General government gross debt
# 14                            Current account balance
#
#                                        Percent change Unnamed: 2  \
# ...

# %%
cols = []
for i in range(len(data_0.columns)):
    cols.append(data_0.columns[i].lower().replace(' ', '_'))
data_0.columns = cols
data_0.head(15)
# Out:
#     country                                 subject_descriptor       2015  \
# 0   Albania            Gross domestic product, constant prices      2.219
# 1   Albania             Gross domestic product, current prices     11.389
# 2   Albania                   Gross domestic product, deflator    194.969
# 3   Albania  Gross domestic product per capita, constant pr...  12,173.62
# 4   Albania                                   Total investment     26.237
# 5   Albania                             Gross national savings     15.804
# 6   Albania                 Inflation, average consumer prices        100
# 7   Albania            Volume of imports of goods and services      0.076
# 8   Albania            Volume of exports of goods and services      5.272
# 9   Albania                                  Unemployment rate       17.1
# 10  Albania                                         Population      2.881
# 11  Albania                         General government revenue      26.44
# ...

# %%
data_15 = data_0[['country', 'subject_descriptor', '2015']]
data_16 = data_0[['country', 'subject_descriptor', '2016']]
data_17 = data_0[['country', 'subject_descriptor', '2017']]
data_18 = data_0[['country', 'subject_descriptor', '2018']]
data_19 = data_0[['country', 'subject_descriptor', '2019']]
data_20 = data_0[['country', 'subject_descriptor', '2020']]
data_15.head(16)
# Out:
#     country                                 subject_descriptor       2015
# 0   Albania            Gross domestic product, constant prices      2.219
# 1   Albania             Gross domestic product, current prices     11.389
# 2   Albania                   Gross domestic product, deflator    194.969
# 3   Albania  Gross domestic product per capita, constant pr...  12,173.62
# 4   Albania                                   Total investment     26.237
# 5   Albania                             Gross national savings     15.804
# 6   Albania                 Inflation, average consumer prices        100
# 7   Albania            Volume of imports of goods and services      0.076
# 8   Albania            Volume of exports of goods and services      5.272
# 9   Albania                                  Unemployment rate       17.1
# 10  Albania                                         Population      2.881
# 11  Albania                         General government revenue      26.44
# ...

# %% [markdown]
# # FROM HERE ALL TRANSFORMATIONS ARE  INCLUDED IN CLEANING FUNCTIONS AT THE END

# %%
def pivot_and_column_names(df):
        df= df.pivot(index='country', columns=df[['subject_descriptor']])
        #rename columns:
        df.columns = ['acc_bal','gross_debt','gov_net_len/borr','gov_rev','gov_expend','gdp_percap_cons','gdp_cons',
                      'gdp_curr', 'gdp_defl', 'gross_savings','inflation_ind','pop','tot_invest', 'unemployment', 
                      'export_g_s', 'import_g_s']
        #arrange order:
        df = df[['acc_bal','gov_rev','gov_expend','gdp_percap_cons','inflation_ind','gov_net_len/borr','tot_invest',
                    'gross_savings','pop', 'unemployment', 
                    'export_g_s', 'import_g_s','gdp_defl','gross_debt','gdp_cons','gdp_curr']]
        return df
pivot_and_column_names(data_20)

# %%
d_15 = column_names(data_15)
d_16 = column_names(data_16)
d_17 = column_names(data_17)
d_18 = column_names(data_18)
d_19 = column_names(data_19)
d_20 = column_names(data_20)
d_15

# %%
#I see the column 'gdp_percap_cons' has commas to separate the 1000s 
#as per error: 'could not convert string to float: '12,173.62''

# https://www.adamsmith.haus/python/answers/how-to-remove-a-comma-from-a-string-in-python

def clean_comma(df):
    for i in df.columns:
        df[i] = df[i].str.replace(',', '')
    return df 
clean_comma(d_15)
clean_comma(d_16)
clean_comma(d_17)
clean_comma(d_18)
clean_comma(d_19)
clean_comma(d_20)

#I will include it in the cleaning function

# %%
#transform dtypes to numerics 
def to_num(df):
    df = df.astype(np.number)
    print(df.dtypes)

to_num(d_15)
to_num(d_16)
to_num(d_17)
to_num(d_18)
to_num(d_19)
to_num(d_20)
display(d_20)

# %%
d_15.to_csv('d_15.csv', index=True)
d_16.to_csv('d_16.csv', index=True)
d_17.to_csv('d_17.csv', index=True)
d_18.to_csv('d_18.csv', index=True)
d_19.to_csv('d_19.csv', index=True)
d_20.to_csv('d_20.csv', index=True)

# %%
d15 = pd.read_csv("d_15.csv")
d16 = pd.read_csv("d_16.csv")
d17 = pd.read_csv("d_17.csv")
d18 = pd.read_csv("d_18.csv")
d19 = pd.read_csv("d_19.csv")
d20 = pd.read_csv("d_20.csv")
d15

# %%
d15.isnull().sum()

# %%
d15.dtypes

# %% [markdown]
# Add 2 categorical columns by region and by economy size

# %% [markdown]
# Region / Continent :
#
# I found this library "pycountry" :
#
# Which through the country code, gives the continent.
# import pycountry_convert as pc
#
# country_code = pc.country_name_to_country_alpha2("China", cn_name_format="default")
# print(country_code)
# continent_name = pc.country_alpha2_to_continent_code(country_code)
# print(continent_name)
# I am going to create a colulmn called "region"

# %%
#clean and convert not ISO recognised country names 
#list of correct contry names (ISO) found here: 
#https://stackoverflow.com/questions/16253060/how-to-convert-country-names-to-iso-3166-1-alpha-2-values-using-python
# 'Kosovo' is not a recognsed country by ISO 3166 so I am going to name it Serbia (keeps the index order) just to get the country code

def replace_wrong_names(df):
    df[['country']] = df[['country']].replace(['Hong Kong SAR',"Korea",'Kosovo', 'Taiwan Province of China', 'The Bahamas' ], ['Hong Kong', 'Korea, Republic of', 'Montenegro','Taiwan, Province of China',  'Bahamas'])
    
# replace_wrong_names(d15)
# replace_wrong_names(d16)
# replace_wrong_names(d17)
# replace_wrong_names(d18)
# replace_wrong_names(d19)
# replace_wrong_names(d20)

# %%
def code_co(df):
    df['code'] = df['country'].apply(pc.country_name_to_country_alpha2)
   

code_co(d15)
code_co(d16)
code_co(d17)
code_co(d18)
code_co(d19)
code_co(d20)




# d15['code'] = d15['country'].apply(pc.country_name_to_country_alpha2)
# d15['code']

# %%
def create_cont(df):
    df['continent'] = df['code'].apply(pc.country_alpha2_to_continent_code)
    df.drop('code', axis=1, inplace=True)
    #rename Kosovo back
    df['country'][43]= 'Kosovo'


create_cont(d15)
create_cont(d16)
create_cont(d17)
create_cont(d18)
create_cont(d19)
create_cont(d20)

# d15['continent'] = d15['code'].apply(pc.country_alpha2_to_continent_code)
# d15['continent'] 
# continents = {
#     'NA': 'North America',
#     'SA': 'South America', 
#     'AS': 'Asia',
#     'OC': 'Australia',
#     'AF': 'Africa',
#     'EU': 'Europe'
# }

# %%
d15

# %% [markdown]
# Economy size:
#
#
#
# % GDP growth Vs LY
# Unemployment
# Population

# %%
#add a new column with a classification (Total expenditure)

# %%
# % of GDP
def spend_class(df):
#   df['spend_class'] = df["gov_expend"].copy()
    labels = ["S1", "S2", "S3","S4"]
    df['spend_class'] = pd.qcut(df["gov_expend"],4, labels = labels)
    
    
spend_class(d20)

# %%
["gov_expend"].isna().sum()

# %%
d15['gross_debt'].describe()

# %%
def gross_debt_class(df):
    labels = ["0%-5%", "5%-20%", "20%-40%", "40%-60%", "Very High"]
    df['debt_class'] = pd.cut(df['gross_debt'],[0,5,20,40,60,228.397000], labels = labels)
    
gross_debt_class(d20)

# %%
d15['tot_invest'].describe()

# %%
def invest_class(df):
    labels = ["0%-20%", "20%-30%", "30%-40%", ">40"]
    df['invest/gdp_class'] = pd.cut(df['tot_invest'],[12,20,30,40,51], labels = labels)
   
invest_class(d20)

# %%
def order_columns(df):
    df= df[['country','continent','acc_bal','gdp_defl','inflation_ind','gob rev','gov_expend','gob_net_len/borr','tot_invest',
                'gross_savings', 'export_g_s', 'import_g_s','gross_debt','pop', 'unemployment','gdp_percap_cons','gdp_cons','gdp_curr']]

# %%
def data_grooming(df):
    df = df.pivot(index='country', columns=df[['subject_descriptor']])
    #rename columns:
    df.columns = ['acc_bal','gross_debt','gov_net_len/borr','gov_rev','gov_expend','gdp_percap_cons','gdp_cons',
                    'gdp_curr', 'gdp_defl', 'gross_savings','inflation_ind','pop','tot_invest', 'unemployment', 
                    'export_g_s', 'import_g_s']
    #arrange order:
    df = df[['acc_bal','gov_rev','gov_expend','gdp_percap_cons','inflation_ind','gov_net_len/borr','tot_invest',
                    'gross_savings','pop', 'unemployment', 
                    'export_g_s', 'import_g_s','gdp_defl','gross_debt','gdp_cons','gdp_curr']]
    #clean commas in 1000s values:
    for i in df.columns:
        df[i] = df[i].str.replace(',', '')
    #transform dtypes to numerics 
    df = df.astype(np.number)
    return df
    
    
def data_cleaning(df):
    df['country'] = df['country'].replace(['Hong Kong SAR',"Korea",'Kosovo','Taiwan Province of China','The Bahamas'], ['Hong Kong','Korea, Republic of','Montenegro','Taiwan, Province of China','Bahamas'])
    df['code'] = df['country'].apply(pc.country_name_to_country_alpha2)
    df['continent'] = df['code'].apply(pc.country_alpha2_to_continent_code)
    df.drop('code', axis=1, inplace=True)
    #rename Kosovo back
    df['country'].replace('Montenegro', 'Kosovo')
    display(df)
    #Spend_class
    #df['spend_class'] = df["gov_expend"].copy()
    labels = ["S1", "S2", "S3","S4"]
    df['spend_class'] = pd.qcut(df["gov_expend"],4, labels = labels)
    display(df)
    #gross_debt_class
    #df['debt_class'] = df["gross_debt"].copy()
    labels = ["0%-5%", "5%-20%", "20%-40%", "40%-60%", "Very High"]
    df['debt_class'] = pd.cut(df['gross_debt'],[0,5,20,40,60,228.397000], labels = labels)
    display(df)
    #invest_class(df):
    #df['invest/gdp_class'] = df["tot_invest"].copy()
    labels = ["0%-20%", "20%-30%", "30%-40%", ">40"]
    df['invest/gdp_class'] = pd.cut(df['tot_invest'],[12,20,30,40,51], labels = labels)
    display(df)
    #reorder columns :
    df = df[['country','continent','spend_class','debt_class','invest/gdp_class','acc_bal','gdp_defl','inflation_ind','gov_rev','gov_expend','gov_net_len/borr','tot_invest','gross_savings', 'export_g_s', 'import_g_s','gross_debt','pop', 'unemployment','gdp_percap_cons','gdp_cons','gdp_curr']]
    display(df)

# %%
d_15_g = data_grooming(data_15)
d_16_g = data_grooming(data_16)
d_17_g = data_grooming(data_17)
d_18_g = data_grooming(data_18)
d_19_g = data_grooming(data_19)
d_20_g = data_grooming(data_20)

# %%
d_20_g
# Out:
#                 acc_bal  gov_rev  gov_expend  gdp_percap_cons  inflation_ind  \
# country
# Albania          -8.677   25.905      32.619         13394.46        108.613
# Algeria         -12.677   30.128      36.868         10747.35        211.180
# Argentina         0.852   33.466      42.092         19685.74        619.207
# Armenia          -3.787   25.247      30.649         12631.53        218.396
# Australia         2.595   36.090      44.674         49088.42        116.175
# ...                 ...      ...         ...              ...            ...
# United Kingdom   -2.502   36.160      48.921         42975.53        108.736
# United States    -2.949   30.804      45.296         59803.38        258.838
# Uruguay          -0.839   28.124      32.793         21200.62        216.725
# Uzbekistan       -5.021   26.356      28.873          7415.02        313.051
# Vietnam           4.391   18.535      22.444         10331.25        282.118
#
# ...

# %%
d_15_g.to_csv('d_15_g.csv', index=True)
d_16_g.to_csv('d_16_g.csv', index=True)
d_17_g.to_csv('d_17_g.csv', index=True)
d_18_g.to_csv('d_18_g.csv', index=True)
d_19_g.to_csv('d_19_g.csv', index=True)
d_20_g.to_csv('d_20_g.csv', index=True)

# %%
dd15 = pd.read_csv("d_15_g.csv")
dd16 = pd.read_csv("d_16_g.csv")
dd17 = pd.read_csv("d_17_g.csv")
dd18 = pd.read_csv("d_18_g.csv")
dd19 = pd.read_csv("d_19_g.csv")
dd20 = pd.read_csv("d_20_g.csv")

# %%
dd20
# Out:
#            country  acc_bal  gov_rev  gov_expend  gdp_percap_cons  \
# 0          Albania   -8.677   25.905      32.619         13394.46
# 1          Algeria  -12.677   30.128      36.868         10747.35
# 2        Argentina    0.852   33.466      42.092         19685.74
# 3          Armenia   -3.787   25.247      30.649         12631.53
# 4        Australia    2.595   36.090      44.674         49088.42
# ..             ...      ...      ...         ...              ...
# 86  United Kingdom   -2.502   36.160      48.921         42975.53
# 87   United States   -2.949   30.804      45.296         59803.38
# 88         Uruguay   -0.839   28.124      32.793         21200.62
# 89      Uzbekistan   -5.021   26.356      28.873          7415.02
# 90         Vietnam    4.391   18.535      22.444         10331.25
#
#     inflation_ind  gov_net_len/borr  tot_invest  gross_savings      pop  \
# 0         108.613            -6.713      22.790         14.074    2.878
# ...

# %%
data_cleaning(dd15)
data_cleaning(dd16)
data_cleaning(dd17)
data_cleaning(dd18)
data_cleaning(dd19)
data_cleaning(dd20)
# Out:
#            country  acc_bal  gov_rev  gov_expend  gdp_percap_cons  \
# 0          Albania   -8.609   26.440      30.758         12173.62
# 1          Algeria  -16.442   30.544      45.811         11616.72
# 2        Argentina   -2.743   35.366      41.366         23933.89
# 3          Armenia   -2.685   21.494      26.331         11074.41
# 4        Australia   -4.637   34.599      37.387         48757.65
# ..             ...      ...      ...         ...              ...
# 86  United Kingdom   -5.165   35.486      39.993         45208.37
# 87   United States   -2.246   31.673      35.205         58385.72
# 88         Uruguay   -0.254   26.607      28.472         22069.82
# 89      Uzbekistan    1.046   24.325      24.567          6458.15
# 90         Vietnam   -0.861   19.190      24.174          8133.27
#
#     inflation_ind  gov_net_len/borr  tot_invest  gross_savings      pop  \
# 0         100.000            -4.318      26.237         15.804    2.881
# ...

# %%
dd20
# Out:
#            country  acc_bal  gov_rev  gov_expend  gdp_percap_cons  \
# 0          Albania   -8.677   25.905      32.619         13394.46
# 1          Algeria  -12.677   30.128      36.868         10747.35
# 2        Argentina    0.852   33.466      42.092         19685.74
# 3          Armenia   -3.787   25.247      30.649         12631.53
# 4        Australia    2.595   36.090      44.674         49088.42
# ..             ...      ...      ...         ...              ...
# 86  United Kingdom   -2.502   36.160      48.921         42975.53
# 87   United States   -2.949   30.804      45.296         59803.38
# 88         Uruguay   -0.839   28.124      32.793         21200.62
# 89      Uzbekistan   -5.021   26.356      28.873          7415.02
# 90         Vietnam    4.391   18.535      22.444         10331.25
#
#     inflation_ind  gov_net_len/borr  tot_invest  gross_savings      pop  ...  \
# 0         108.613            -6.713      22.790         14.074    2.878  ...
# ...

# %%
# d20['country'] = d20['country'].replace(['Hong Kong SAR',"Korea",'Kosovo','Taiwan Province of China','The Bahamas'], ['Hong Kong','Korea, Republic of','Montenegro','Taiwan, Province of China','Bahamas'])
# display(d20.head(40))
# d20['code'] = d20['country'].apply(pc.country_name_to_country_alpha2)
# display(d20.head(40))
# d20['continent'] = d20['code'].apply(pc.country_alpha2_to_continent_code)
# display(d20.head(40))
# d20.drop('code', axis=1, inplace=True)
# display(d20.head(40))
#     #rename Kosovo back
# d20['country'].replace('Montenegro', 'Kosovo')
# display(d20.head(40))

# %% [markdown]
# Saving to csv

# %%
dd15.to_csv('final_15.csv', index=False)
dd16.to_csv('final_16.csv', index=False)
dd17.to_csv('final_17.csv', index=False)
dd18.to_csv('final_18.csv', index=False)
dd19.to_csv('final_19.csv', index=False)
dd20.to_csv('final_20.csv', index=False)

# %%
gdp_15= pd.read_csv("final_15.csv", sep=',')
gdp_15
# Out:
#            country  acc_bal  gov_rev  gov_expend  gdp_percap_cons  \
# 0          Albania   -8.609   26.440      30.758         12173.62
# 1          Algeria  -16.442   30.544      45.811         11616.72
# 2        Argentina   -2.743   35.366      41.366         23933.89
# 3          Armenia   -2.685   21.494      26.331         11074.41
# 4        Australia   -4.637   34.599      37.387         48757.65
# ..             ...      ...      ...         ...              ...
# 86  United Kingdom   -5.165   35.486      39.993         45208.37
# 87   United States   -2.246   31.673      35.205         58385.72
# 88         Uruguay   -0.254   26.607      28.472         22069.82
# 89      Uzbekistan    1.046   24.325      24.567          6458.15
# 90         Vietnam   -0.861   19.190      24.174          8133.27
#
#     inflation_ind  gov_net_len/borr  tot_invest  gross_savings      pop  ...  \
# 0         100.000            -4.318      26.237         15.804    2.881  ...
# ...

# %% [markdown]
# Saving to SQL DB

# %%
password = getpass()
# Out:
# ········

# %%
password = getpass()

database_connection = sqlalchemy.create_engine('mysql+pymysql://root:'+password+'@127.0.0.1:3306/gdp')
                                             
dd15.to_sql(con=database_connection, name='gdp_15', if_exists='replace')
dd16.to_sql(con=database_connection, name='gdp_16', if_exists='replace')
dd17.to_sql(con=database_connection, name='gdp_17', if_exists='replace')
dd18.to_sql(con=database_connection, name='gdp_18', if_exists='replace')
dd19.to_sql(con=database_connection, name='gdp_19', if_exists='replace')
dd20.to_sql(con=database_connection, name='gdp_20', if_exists='replace')

# %%
# !git add .

# %%
# !git commit -m'start'
# Out:
# [main a388d93] start
#  15 files changed, 13324 insertions(+), 2114 deletions(-)
#  create mode 100644 d_15_g.csv
#  create mode 100644 d_16_g.csv
#  create mode 100644 d_17_g.csv
#  create mode 100644 d_18_g.csv
#  create mode 100644 d_19_g.csv
#  delete mode 100644 d_20.csv
#  create mode 100644 d_20_g.csv
#  create mode 100644 final_15.csv
#  create mode 100644 final_16.csv
#  create mode 100644 final_17.csv
#  create mode 100644 final_18.csv
#  create mode 100644 final_19.csv
#  create mode 100644 final_20.csv

# %%
# !git push
# Out:
# Enumerating objects: 21, done.
# Counting objects: 100% (20/20), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (16/16), done.
# Writing objects: 100% (17/17), 82.43 KiB | 1.96 MiB/s, done.
# Total 17 (delta 6), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (6/6), completed with 1 local object.
# To https://github.com/chrislacarte/Country-GDP-and-Debt-predictor-ML-
#    8c44dcc..a388d93  main -> main
